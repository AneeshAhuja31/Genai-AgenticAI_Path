# %%
import os
from dotenv import load_dotenv
load_dotenv()

NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")

# %%
from langchain_community.graphs import Neo4jGraph
graph = Neo4jGraph(url=NEO4J_URI,username=NEO4J_USERNAME,password=NEO4J_PASSWORD)
graph
# Out:
# Unable to retrieve routing information
# ---------------------------------------------------------------------------
# ServiceUnavailable                        Traceback (most recent call last)
# File c:\Users\HP\anaconda3\envs\my_env\lib\site-packages\langchain_community\graphs\neo4j_graph.py:415, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     414 try:
# --> 415     self._driver.verify_connectivity()
#     416 except neo4j.exceptions.ServiceUnavailable:
#
# File c:\Users\HP\anaconda3\envs\my_env\lib\site-packages\neo4j\_sync\driver.py:1082, in Driver.verify_connectivity(self, **config)
#    1081 session_config = self._read_session_config(config)
# -> 1082 self._get_server_info(session_config)
#
# File c:\Users\HP\anaconda3\envs\my_env\lib\site-packages\neo4j\_sync\driver.py:1297, in Driver._get_server_info(self, session_config)
#    1296 with self._session(session_config) as session:
# -> 1297     return session._get_server_info()
#
# File c:\Users\HP\anaconda3\envs\my_env\lib\site-packages\neo4j\_sync\work\session.py:183, in Session._get_server_info(self)
#     182 assert not self._connection
# --> 183 self._connect(READ_ACCESS, liveness_check_timeout=0)
#     184 server_info = self._connection.server_info
#
# File c:\Users\HP\anaconda3\envs\my_env\lib\site-packages\neo4j\_sync\work\session.py:136, in Session._connect(self, access_mode, **acquire_kwargs)
#     135 try:
# --> 136     super()._connect(
#     137         access_mode, auth=self._config.auth, **acquire_kwargs
#     138     )
#     139 except asyncio.CancelledError:
#
# File c:\Users\HP\anaconda3\envs\my_env\lib\site-packages\neo4j\_sync\work\workspace.py:186, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     185 ssr_enabled = self._pool.ssr_enabled
# --> 186 target_db = self._get_routing_target_database(
#     187     acquire_auth, ssr_enabled=ssr_enabled
#     188 )
#     189 acquire_kwargs_ = {
#     190     "access_mode": access_mode,
#     191     "timeout": acquisition_timeout,
#    (...)
#     196     "database_callback": self._make_db_resolution_callback(),
#     197 }
#
# File c:\Users\HP\anaconda3\envs\my_env\lib\site-packages\neo4j\_sync\work\workspace.py:260, in Workspace._get_routing_target_database(self, acquire_auth, ssr_enabled)
#     259 log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 260 self._pool.update_routing_table(
#     261     database=self._config.database,
#     262     imp_user=self._config.impersonated_user,
#     263     bookmarks=self._get_bookmarks(),
#     264     auth=acquire_auth,
#     265     acquisition_timeout=acquisition_timeout,
#     266     database_callback=self._make_db_resolution_callback(),
#     267 )
#     268 return AcquisitionDatabase(self._config.database)
#
# File c:\Users\HP\anaconda3\envs\my_env\lib\site-packages\neo4j\_sync\io\_pool.py:1011, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#    1010 log.error("Unable to retrieve routing information")
# -> 1011 raise ServiceUnavailable("Unable to retrieve routing information")
#
# ServiceUnavailable: Unable to retrieve routing information
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 from langchain_community.graphs import Neo4jGraph
# ----> 2 graph = Neo4jGraph(url=NEO4J_URI,username=NEO4J_USERNAME,password=NEO4J_PASSWORD)
#       3 graph
#
# File c:\Users\HP\anaconda3\envs\my_env\lib\site-packages\langchain_core\_api\deprecation.py:222, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     220     warned = True
#     221     emit_warning()
# --> 222 return wrapped(self, *args, **kwargs)
#
# File c:\Users\HP\anaconda3\envs\my_env\lib\site-packages\langchain_community\graphs\neo4j_graph.py:417, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     415     self._driver.verify_connectivity()
#     416 except neo4j.exceptions.ServiceUnavailable:
# --> 417     raise ValueError(
#     418         "Could not connect to Neo4j database. "
#     419         "Please ensure that the url is correct"
#     420     )
#     421 except neo4j.exceptions.AuthError:
#     422     raise ValueError(
#     423         "Could not connect to Neo4j database. "
#     424         "Please ensure that the username and password are correct"
#     425     )
#
# ValueError: Could not connect to Neo4j database. Please ensure that the url is correct
